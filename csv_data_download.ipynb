# %%
import requests
import pandas as pd

url = 'https://finnhub.io/api/v1/stock/insider-transactions?symbol=BRK&token=cqbeha1r01qvu0jvmnngcqbeha1r01qvu0jvmno0'

response = requests.get(url)
import json
data = response.json()
df = pd.DataFrame(data["data"])
df.to_csv('./InsiderTranDATA/BRK.csv', index=False, header=True)

# %%
read_df = pd.read_csv('VRNT_insider_tran_0603.csv', delimiter=',')

# %%
read_df
# Out:
#     change  currency  filingDate                    id  isDerivative  \
# 0  -375000       NaN  2024-06-24  0001166388-24-000136         False
# 1    -7177       NaN  2024-06-20  0001166388-24-000134         False
# 2    -7100       NaN  2024-06-20  0001166388-24-000134         False
# 3    -2634       NaN  2024-06-20  0001166388-24-000132         False
# 4    -2320       NaN  2024-06-20  0001166388-24-000132         False
# ..     ...       ...         ...                   ...           ...
# 62   -2270       NaN  2023-09-15  0001166388-23-000159         False
# 63   -1682       NaN  2023-09-14  0001166388-23-000157         False
# 64   -5829       NaN  2023-09-14  0001166388-23-000155         False
# 65  -30000       NaN  2023-08-22  0001166388-23-000136         False
# 66  -29230       NaN  2023-07-21  0001166388-23-000134         False
#
#            name    share source symbol transactionCode transactionDate  \
# ...

# %%
# url = 'https://finnhub.io/api/v1/stock/insider-transactions?symbol=AAPL&token=cqbeha1r01qvu0jvmnngcqbeha1r01qvu0jvmno0'
# response = requests.get(url)
# data = response.json()
# insider_df = pd.DataFrame(data["data"])
# insider_df
